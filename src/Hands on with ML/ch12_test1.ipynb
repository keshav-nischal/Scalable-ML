# %%
print("hello world")
# Out:
# hello world

# %%
# what filters mean. what is vertical vs horizontal filters. where do they come into picture in training a model for visual task
# what are strides
# how not padding leads to pixel loss as mentioned in 456


ec_ao_nu_search_non-brand_generico_equipamento-puericultura_bebe_passeio
ec_ao_core_search_non-brand_generico_telemoveis-e-pacotes-de-tv_telemoveis-e-smartphones_samsung
